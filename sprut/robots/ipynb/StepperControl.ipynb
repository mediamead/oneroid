# %%
import matplotlib.pyplot as plt

G = [0, 100, 150, 100]

X = []
V = []
A = []

a = 0
v = 0
x = 0

for i in range(100):
    a = 1
    v += a
    x += v
    
    A.append(a)
    V.append(v)
    X.append(x)

# %%
plt.xlabel('t')
plt.plot(X, 'r')
plt.ylabel('x')
plt.show()

# %%
plt.plot(V, 'r')
plt.ylabel('v')
plt.show()

# %%
plt.plot(A, 'r')
plt.ylabel('a')
plt.show()
